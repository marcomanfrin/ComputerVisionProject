# %% [markdown]
# # V2 - Custom CNN
# ## Plant Disease Detection — PyTorch CNN from scratch (38 classes)

# %%
# ── Cell 1: Setup & Imports ───────────────────────────────────────────────────
import sys, os, json, time, copy
from pathlib import Path

import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from tqdm import tqdm

import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader
from torchvision import datasets, transforms

from sklearn.metrics import (accuracy_score, precision_score,
                             recall_score, f1_score, confusion_matrix,
                             classification_report)

# ── Paths ─────────────────────────────────────────────────────────────────────
PROJECT_ROOT = Path("..").resolve()
DATA_DIR     = PROJECT_ROOT / "data" / "processed"
RESULTS_DIR  = PROJECT_ROOT / "results"
MODELS_DIR   = RESULTS_DIR / "models" / "v2_custom_cnn"
METRICS_DIR  = RESULTS_DIR / "metrics"
PLOTS_DIR    = RESULTS_DIR / "plots"

for d in [MODELS_DIR, METRICS_DIR, PLOTS_DIR]:
    d.mkdir(parents=True, exist_ok=True)

# ── Device (MPS on Apple Silicon, CUDA if available, otherwise CPU) ───────────
if torch.backends.mps.is_available():
    DEVICE = torch.device("mps")
elif torch.cuda.is_available():
    DEVICE = torch.device("cuda")
else:
    DEVICE = torch.device("cpu")

print(f"Device: {DEVICE}")
print(f"PyTorch: {torch.__version__}")

# ── Hyperparameters ───────────────────────────────────────────────────────────
IMG_SIZE    = 224
BATCH_SIZE  = 64   # MPS handles larger batches than CPU
LR          = 1e-3
EPOCHS      = 100
PATIENCE    = 10
NUM_WORKERS = 0    # on MPS, DataLoaders run with num_workers=0

FAST_MODE = False
print(f"Fast mode: {FAST_MODE}")
# Out:
# Device: mps
# PyTorch: 2.12.0
# Fast mode: False

# %%
# ── Cell 2: Dataset & DataLoaders ─────────────────────────────────────────────
IMAGENET_MEAN = [0.485, 0.456, 0.406]
IMAGENET_STD  = [0.229, 0.224, 0.225]

train_transform = transforms.Compose([
    transforms.Resize((IMG_SIZE, IMG_SIZE)),
    transforms.RandomRotation(15),
    transforms.RandomHorizontalFlip(),
    transforms.ColorJitter(brightness=0.2, contrast=0.2, saturation=0.2),
    transforms.RandomAffine(degrees=10, translate=(0.1, 0.1)),
    transforms.ToTensor(),
    transforms.Normalize(IMAGENET_MEAN, IMAGENET_STD),
])

val_test_transform = transforms.Compose([
    transforms.Resize((IMG_SIZE, IMG_SIZE)),
    transforms.ToTensor(),
    transforms.Normalize(IMAGENET_MEAN, IMAGENET_STD),
])

train_dataset = datasets.ImageFolder(DATA_DIR / "train", transform=train_transform)
val_dataset   = datasets.ImageFolder(DATA_DIR / "val",   transform=val_test_transform)
test_dataset  = datasets.ImageFolder(DATA_DIR / "test",  transform=val_test_transform)

# optional: subsample for quick tests on CPU
if FAST_MODE:
    def subsample(ds, frac=0.1):
        n = max(1, int(len(ds) * frac))
        idx = torch.randperm(len(ds))[:n].tolist()
        return torch.utils.data.Subset(ds, idx)
    train_dataset = subsample(train_dataset)
    val_dataset   = subsample(val_dataset)
    test_dataset  = subsample(test_dataset)

# ── WeightedRandomSampler to balance the train set ───────────────────────────
# The new dataset is imbalanced (~36× between min and max class).
# We sample each example with weight = 1 / count(class) so each batch is
# approximately class-balanced. NOTE: shuffle must be False when using a sampler.
def _targets(ds):
    if isinstance(ds, torch.utils.data.Subset):
        base = ds.dataset
        return [base.samples[i][1] for i in ds.indices]
    return [y for _, y in ds.samples]

train_targets = np.array(_targets(train_dataset))
class_counts  = np.bincount(train_targets)
class_weights = 1.0 / class_counts
sample_weights = class_weights[train_targets]

train_sampler = torch.utils.data.WeightedRandomSampler(
    weights=torch.as_tensor(sample_weights, dtype=torch.double),
    num_samples=len(sample_weights),
    replacement=True,
)

train_loader = DataLoader(train_dataset, batch_size=BATCH_SIZE, sampler=train_sampler,
                          num_workers=NUM_WORKERS, pin_memory=True)
val_loader   = DataLoader(val_dataset,   batch_size=BATCH_SIZE, shuffle=False,
                          num_workers=NUM_WORKERS, pin_memory=True)
test_loader  = DataLoader(test_dataset,  batch_size=BATCH_SIZE, shuffle=False,
                          num_workers=NUM_WORKERS, pin_memory=True)

CLASS_NAMES = train_dataset.classes if hasattr(train_dataset, "classes") else train_dataset.dataset.classes
NUM_CLASSES = len(CLASS_NAMES)

print(f"Classes: {NUM_CLASSES}")
print(f"Train: {len(train_dataset)} | Val: {len(val_dataset)} | Test: {len(test_dataset)}")
print(f"Sampler: WeightedRandomSampler (min count={class_counts.min()}, max count={class_counts.max()}, "
      f"ratio={class_counts.max()/class_counts.min():.1f}×)")
# Out:
# Classes: 38
# Train: 43443 | Val: 5422 | Test: 5439
# Sampler: WeightedRandomSampler (min count=121, max count=4405, ratio=36.4×)

# %%
# ── Cell 3: CNN Model (~0.66M parameters) ────────────────────────────────────
class ConvBlock(nn.Module):
    def __init__(self, in_ch, out_ch):
        super().__init__()
        self.block = nn.Sequential(
            nn.Conv2d(in_ch, out_ch, kernel_size=3, padding=1, bias=False),
            nn.BatchNorm2d(out_ch),
            nn.ReLU(inplace=True),
        )
    def forward(self, x):
        return self.block(x)


class PlantDiseaseNet(nn.Module):
    """4 Conv+BN+ReLU blocks → GlobalAvgPool → Dense 512→256→num_classes."""
    def __init__(self, num_classes=38):
        super().__init__()
        self.features = nn.Sequential(
            ConvBlock(3,   32), nn.MaxPool2d(2),   # → (B, 32, 112, 112)
            ConvBlock(32,  64), nn.MaxPool2d(2),   # → (B, 64,  56,  56)
            ConvBlock(64, 128), nn.MaxPool2d(2),   # → (B,128,  28,  28)
            ConvBlock(128,256),                     # → (B,256,  28,  28)
        )
        self.pool = nn.AdaptiveAvgPool2d(1)         # → (B,256,   1,   1)
        self.classifier = nn.Sequential(
            nn.Linear(256, 512), nn.ReLU(inplace=True), nn.Dropout(0.5),
            nn.Linear(512, 256), nn.ReLU(inplace=True), nn.Dropout(0.3),
            nn.Linear(256, num_classes),
        )

    def forward(self, x):
        x = self.features(x)
        x = self.pool(x).flatten(1)
        return self.classifier(x)


model = PlantDiseaseNet(num_classes=NUM_CLASSES).to(DEVICE)
total_params = sum(p.numel() for p in model.parameters())
print(f"Total parameters: {total_params:,}  (~{total_params/1e6:.1f}M)")

criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.parameters(), lr=LR)
scheduler = optim.lr_scheduler.ReduceLROnPlateau(optimizer, factor=0.1, patience=5)
print("Model, loss and optimizer ready ✅")
# Out:
# Total parameters: 661,574  (~0.7M)
# Model, loss and optimizer ready ✅

# %%
# ── Cell 4: Training Loop with Early Stopping (with resume) ──────────────────
def train_epoch(model, loader, criterion, optimizer, device):
    model.train()
    running_loss, correct, total = 0.0, 0, 0
    for images, labels in loader:
        images, labels = images.to(device), labels.to(device)
        optimizer.zero_grad()
        outputs = model(images)
        loss = criterion(outputs, labels)
        loss.backward()
        optimizer.step()
        running_loss += loss.item() * images.size(0)
        correct += (outputs.argmax(1) == labels).sum().item()
        total   += images.size(0)
    return running_loss / total, correct / total


def validate(model, loader, criterion, device):
    model.eval()
    running_loss, correct, total = 0.0, 0, 0
    with torch.no_grad():
        for images, labels in loader:
            images, labels = images.to(device), labels.to(device)
            outputs = model(images)
            loss = criterion(outputs, labels)
            running_loss += loss.item() * images.size(0)
            correct += (outputs.argmax(1) == labels).sum().item()
            total   += images.size(0)
    return running_loss / total, correct / total


checkpoint_path = MODELS_DIR / "checkpoint.pth"

# ── Resume from checkpoint if it exists ──────────────────────────────────────
if checkpoint_path.exists():
    ckpt = torch.load(checkpoint_path, map_location=DEVICE, weights_only=False)
    model.load_state_dict(ckpt["model_state_dict"])
    best_val_loss  = ckpt["val_loss"]
    start_epoch    = ckpt["epoch"] + 1
    history        = ckpt.get("history", {"train_loss": [], "val_loss": [], "train_acc": [], "val_acc": []})
    print(f"Resumed from epoch {ckpt['epoch']} — best val loss {best_val_loss:.4f}, val acc {ckpt['val_acc']:.4f}")
else:
    best_val_loss  = float("inf")
    start_epoch    = 1
    history        = {"train_loss": [], "val_loss": [], "train_acc": [], "val_acc": []}
    print("No checkpoint found, training from scratch.")

best_model_wts = copy.deepcopy(model.state_dict())
patience_count = 0
t0 = time.time()

print(f"Training on {DEVICE} — epoch {start_epoch}→{EPOCHS}, early stopping patience={PATIENCE}\n")

for epoch in range(start_epoch, EPOCHS + 1):
    tr_loss, tr_acc = train_epoch(model, train_loader, criterion, optimizer, DEVICE)
    vl_loss, vl_acc = validate(model, val_loader, criterion, DEVICE)
    scheduler.step(vl_loss)

    history["train_loss"].append(tr_loss)
    history["val_loss"].append(vl_loss)
    history["train_acc"].append(tr_acc)
    history["val_acc"].append(vl_acc)

    improved = vl_loss < best_val_loss
    if improved:
        best_val_loss  = vl_loss
        best_model_wts = copy.deepcopy(model.state_dict())
        torch.save({"epoch": epoch,
                    "model_state_dict": best_model_wts,
                    "val_loss": best_val_loss,
                    "val_acc": vl_acc,
                    "history": history}, checkpoint_path)
        patience_count = 0
        tag = " ✓ saved"
    else:
        patience_count += 1
        tag = f" (patience {patience_count}/{PATIENCE})"

    print(f"Epoch {epoch:3d}/{EPOCHS} | "
          f"train loss {tr_loss:.4f} acc {tr_acc:.4f} | "
          f"val loss {vl_loss:.4f} acc {vl_acc:.4f}{tag}")

    if patience_count >= PATIENCE:
        print(f"\nEarly stopping at epoch {epoch}.")
        break

elapsed = time.time() - t0
print(f"\nTraining complete in {elapsed/60:.1f} additional min")
print(f"Best val loss: {best_val_loss:.4f}")

with open(METRICS_DIR / "v2_history.json", "w") as f:
    json.dump(history, f, indent=2)
print("History saved ✅")
# Out:
# No checkpoint found, training from scratch.
# Training on mps — epoch 1→100, early stopping patience=10
#
# Epoch   1/100 | train loss 1.8270 acc 0.4487 | val loss 1.1402 acc 0.6459 ✓ saved
# Epoch   2/100 | train loss 0.9471 acc 0.6952 | val loss 1.0256 acc 0.6885 ✓ saved
# Epoch   3/100 | train loss 0.6905 acc 0.7741 | val loss 0.5446 acc 0.8241 ✓ saved
# Epoch   4/100 | train loss 0.5595 acc 0.8161 | val loss 0.4317 acc 0.8608 ✓ saved
# Epoch   5/100 | train loss 0.4843 acc 0.8417 | val loss 0.5738 acc 0.8150 (patience 1/10)
# Epoch   6/100 | train loss 0.4205 acc 0.8604 | val loss 0.2900 acc 0.9019 ✓ saved
# Epoch   7/100 | train loss 0.3822 acc 0.8752 | val loss 0.2741 acc 0.9089 ✓ saved
# Epoch   8/100 | train loss 0.3356 acc 0.8906 | val loss 0.2353 acc 0.9224 ✓ saved
# Epoch   9/100 | train loss 0.3065 acc 0.9001 | val loss 0.2086 acc 0.9312 ✓ saved
# Epoch  10/100 | train loss 0.2758 acc 0.9099 | val loss 0.2599 acc 0.9135 (patience 1/10)
# Epoch  11/100 | train loss 0.2540 acc 0.9175 | val loss 0.1736 acc 0.9430 ✓ saved
# Epoch  12/100 | train loss 0.2377 acc 0.9226 | val loss 0.1569 acc 0.9473 ✓ saved
# Epoch  13/100 | train loss 0.2110 acc 0.9296 | val loss 0.1273 acc 0.9556 ✓ saved
# Epoch  14/100 | train loss 0.2106 acc 0.9323 | val loss 0.2329 acc 0.9255 (patience 1/10)
# Epoch  15/100 | train loss 0.1838 acc 0.9401 | val loss 0.2031 acc 0.9367 (patience 2/10)
# Epoch  16/100 | train loss 0.1795 acc 0.9416 | val loss 0.1365 acc 0.9535 (patience 3/10)
# Epoch  17/100 | train loss 0.1652 acc 0.9461 | val loss 0.1301 acc 0.9570 (patience 4/10)
# Epoch  18/100 | train loss 0.1604 acc 0.9473 | val loss 0.1307 acc 0.9563 (patience 5/10)
# Epoch  19/100 | train loss 0.1506 acc 0.9492 | val loss 0.1112 acc 0.9642 ✓ saved
# Epoch  20/100 | train loss 0.1382 acc 0.9546 | val loss 0.1498 acc 0.9517 (patience 1/10)
# Epoch  21/100 | train loss 0.1353 acc 0.9556 | val loss 0.1587 acc 0.9519 (patience 2/10)
# Epoch  22/100 | train loss 0.1355 acc 0.9561 | val loss 0.0806 acc 0.9745 ✓ saved
# Epoch  23/100 | train loss 0.1214 acc 0.9597 | val loss 0.0774 acc 0.9744 ✓ saved
# Epoch  24/100 | train loss 0.1213 acc 0.9613 | val loss 0.0585 acc 0.9795 ✓ saved
# Epoch  25/100 | train loss 0.1115 acc 0.9642 | val loss 0.0939 acc 0.9705 (patience 1/10)
# Epoch  26/100 | train loss 0.1083 acc 0.9651 | val loss 0.0713 acc 0.9758 (patience 2/10)
# Epoch  27/100 | train loss 0.1039 acc 0.9661 | val loss 0.0499 acc 0.9840 ✓ saved
# Epoch  28/100 | train loss 0.0988 acc 0.9678 | val loss 0.0620 acc 0.9810 (patience 1/10)
# Epoch  29/100 | train loss 0.1019 acc 0.9669 | val loss 0.0558 acc 0.9810 (patience 2/10)
# Epoch  30/100 | train loss 0.0906 acc 0.9704 | val loss 0.0487 acc 0.9830 ✓ saved
# Epoch  31/100 | train loss 0.0945 acc 0.9695 | val loss 0.0675 acc 0.9786 (patience 1/10)
# Epoch  32/100 | train loss 0.0853 acc 0.9721 | val loss 0.1178 acc 0.9622 (patience 2/10)
# Epoch  33/100 | train loss 0.0881 acc 0.9713 | val loss 0.0839 acc 0.9727 (patience 3/10)
# Epoch  34/100 | train loss 0.0813 acc 0.9732 | val loss 0.0610 acc 0.9817 (patience 4/10)
# Epoch  35/100 | train loss 0.0777 acc 0.9755 | val loss 0.0555 acc 0.9819 (patience 5/10)
# Epoch  36/100 | train loss 0.0812 acc 0.9729 | val loss 0.0425 acc 0.9862 ✓ saved
# Epoch  37/100 | train loss 0.0721 acc 0.9766 | val loss 0.0805 acc 0.9744 (patience 1/10)
# Epoch  38/100 | train loss 0.0692 acc 0.9769 | val loss 0.0440 acc 0.9865 (patience 2/10)
# Epoch  39/100 | train loss 0.0751 acc 0.9762 | val loss 0.0617 acc 0.9832 (patience 3/10)
# Epoch  40/100 | train loss 0.0705 acc 0.9776 | val loss 0.0484 acc 0.9819 (patience 4/10)
# Epoch  41/100 | train loss 0.0631 acc 0.9800 | val loss 0.0944 acc 0.9749 (patience 5/10)
# Epoch  42/100 | train loss 0.0657 acc 0.9790 | val loss 0.1060 acc 0.9705 (patience 6/10)
# Epoch  43/100 | train loss 0.0436 acc 0.9852 | val loss 0.0271 acc 0.9926 ✓ saved
# Epoch  44/100 | train loss 0.0325 acc 0.9893 | val loss 0.0264 acc 0.9926 ✓ saved
# Epoch  45/100 | train loss 0.0293 acc 0.9902 | val loss 0.0243 acc 0.9928 ✓ saved
# Epoch  46/100 | train loss 0.0260 acc 0.9914 | val loss 0.0253 acc 0.9919 (patience 1/10)
# Epoch  47/100 | train loss 0.0267 acc 0.9910 | val loss 0.0238 acc 0.9930 ✓ saved
# Epoch  48/100 | train loss 0.0237 acc 0.9922 | val loss 0.0228 acc 0.9930 ✓ saved
# Epoch  49/100 | train loss 0.0237 acc 0.9928 | val loss 0.0230 acc 0.9935 (patience 1/10)
# Epoch  50/100 | train loss 0.0243 acc 0.9920 | val loss 0.0221 acc 0.9930 ✓ saved
# Epoch  51/100 | train loss 0.0230 acc 0.9922 | val loss 0.0223 acc 0.9930 (patience 1/10)
# Epoch  52/100 | train loss 0.0225 acc 0.9926 | val loss 0.0235 acc 0.9932 (patience 2/10)
# Epoch  53/100 | train loss 0.0211 acc 0.9927 | val loss 0.0203 acc 0.9939 ✓ saved
# Epoch  54/100 | train loss 0.0210 acc 0.9932 | val loss 0.0223 acc 0.9937 (patience 1/10)
# Epoch  55/100 | train loss 0.0209 acc 0.9931 | val loss 0.0210 acc 0.9939 (patience 2/10)
# Epoch  56/100 | train loss 0.0188 acc 0.9936 | val loss 0.0190 acc 0.9947 ✓ saved
# Epoch  57/100 | train loss 0.0207 acc 0.9930 | val loss 0.0207 acc 0.9945 (patience 1/10)
# Epoch  58/100 | train loss 0.0216 acc 0.9925 | val loss 0.0184 acc 0.9947 ✓ saved
# Epoch  59/100 | train loss 0.0183 acc 0.9940 | val loss 0.0184 acc 0.9948 ✓ saved
# Epoch  60/100 | train loss 0.0170 acc 0.9939 | val loss 0.0204 acc 0.9945 (patience 1/10)
# Epoch  61/100 | train loss 0.0185 acc 0.9941 | val loss 0.0198 acc 0.9941 (patience 2/10)
# Epoch  62/100 | train loss 0.0191 acc 0.9938 | val loss 0.0221 acc 0.9934 (patience 3/10)
# Epoch  63/100 | train loss 0.0188 acc 0.9940 | val loss 0.0188 acc 0.9947 (patience 4/10)
# Epoch  64/100 | train loss 0.0202 acc 0.9934 | val loss 0.0187 acc 0.9945 (patience 5/10)
# Epoch  65/100 | train loss 0.0158 acc 0.9947 | val loss 0.0193 acc 0.9948 (patience 6/10)
# Epoch  66/100 | train loss 0.0165 acc 0.9948 | val loss 0.0177 acc 0.9954 ✓ saved
# Epoch  67/100 | train loss 0.0171 acc 0.9944 | val loss 0.0180 acc 0.9950 (patience 1/10)
# Epoch  68/100 | train loss 0.0158 acc 0.9948 | val loss 0.0173 acc 0.9952 ✓ saved
# Epoch  69/100 | train loss 0.0164 acc 0.9945 | val loss 0.0173 acc 0.9954 (patience 1/10)
# Epoch  70/100 | train loss 0.0171 acc 0.9942 | val loss 0.0184 acc 0.9950 (patience 2/10)
# Epoch  71/100 | train loss 0.0155 acc 0.9947 | val loss 0.0173 acc 0.9952 (patience 3/10)
# Epoch  72/100 | train loss 0.0153 acc 0.9950 | val loss 0.0175 acc 0.9956 (patience 4/10)
# Epoch  73/100 | train loss 0.0154 acc 0.9952 | val loss 0.0175 acc 0.9954 (patience 5/10)
# Epoch  74/100 | train loss 0.0163 acc 0.9947 | val loss 0.0173 acc 0.9954 (patience 6/10)
# Epoch  75/100 | train loss 0.0153 acc 0.9948 | val loss 0.0179 acc 0.9956 (patience 7/10)
# Epoch  76/100 | train loss 0.0157 acc 0.9946 | val loss 0.0175 acc 0.9952 (patience 8/10)
# Epoch  77/100 | train loss 0.0155 acc 0.9951 | val loss 0.0173 acc 0.9958 (patience 9/10)
# Epoch  78/100 | train loss 0.0151 acc 0.9953 | val loss 0.0172 acc 0.9952 ✓ saved
# Epoch  79/100 | train loss 0.0163 acc 0.9944 | val loss 0.0176 acc 0.9954 (patience 1/10)
# Epoch  80/100 | train loss 0.0156 acc 0.9951 | val loss 0.0173 acc 0.9956 (patience 2/10)
# Epoch  81/100 | train loss 0.0154 acc 0.9952 | val loss 0.0173 acc 0.9956 (patience 3/10)
# Epoch  82/100 | train loss 0.0145 acc 0.9951 | val loss 0.0171 acc 0.9954 ✓ saved
# Epoch  83/100 | train loss 0.0152 acc 0.9950 | val loss 0.0180 acc 0.9952 (patience 1/10)
# Epoch  84/100 | train loss 0.0151 acc 0.9954 | val loss 0.0178 acc 0.9958 (patience 2/10)
# Epoch  85/100 | train loss 0.0141 acc 0.9956 | val loss 0.0173 acc 0.9956 (patience 3/10)
# Epoch  86/100 | train loss 0.0154 acc 0.9949 | val loss 0.0169 acc 0.9954 ✓ saved
# Epoch  87/100 | train loss 0.0163 acc 0.9948 | val loss 0.0169 acc 0.9959 ✓ saved
# Epoch  88/100 | train loss 0.0153 acc 0.9948 | val loss 0.0186 acc 0.9950 (patience 1/10)
# Epoch  89/100 | train loss 0.0153 acc 0.9951 | val loss 0.0175 acc 0.9954 (patience 2/10)
# Epoch  90/100 | train loss 0.0153 acc 0.9950 | val loss 0.0172 acc 0.9956 (patience 3/10)
# Epoch  91/100 | train loss 0.0162 acc 0.9947 | val loss 0.0177 acc 0.9956 (patience 4/10)
# Epoch  92/100 | train loss 0.0157 acc 0.9946 | val loss 0.0176 acc 0.9958 (patience 5/10)
# Epoch  93/100 | train loss 0.0139 acc 0.9953 | val loss 0.0179 acc 0.9954 (patience 6/10)
# Epoch  94/100 | train loss 0.0142 acc 0.9954 | val loss 0.0172 acc 0.9954 (patience 7/10)
# Epoch  95/100 | train loss 0.0159 acc 0.9949 | val loss 0.0172 acc 0.9956 (patience 8/10)
# Epoch  96/100 | train loss 0.0143 acc 0.9952 | val loss 0.0168 acc 0.9958 ✓ saved
# Epoch  97/100 | train loss 0.0169 acc 0.9943 | val loss 0.0180 acc 0.9948 (patience 1/10)
# Epoch  98/100 | train loss 0.0155 acc 0.9953 | val loss 0.0176 acc 0.9954 (patience 2/10)
# Epoch  99/100 | train loss 0.0160 acc 0.9948 | val loss 0.0180 acc 0.9954 (patience 3/10)
# Epoch 100/100 | train loss 0.0153 acc 0.9948 | val loss 0.0174 acc 0.9954 (patience 4/10)
#
# Training complete in 204.4 additional min
# Best val loss: 0.0168
# History saved ✅

# %%
# ── Cell 5: Evaluate on the Test Set ──────────────────────────────────────────
# load the best checkpoint
ckpt = torch.load(checkpoint_path, map_location=DEVICE, weights_only=False)
model.load_state_dict(ckpt["model_state_dict"])
model.eval()

all_preds, all_labels = [], []
with torch.no_grad():
    for images, labels in test_loader:
        images = images.to(DEVICE)
        preds  = model(images).argmax(1).cpu()
        all_preds.extend(preds.tolist())
        all_labels.extend(labels.tolist())

acc      = accuracy_score(all_labels, all_preds)
prec_w   = precision_score(all_labels, all_preds, average="weighted", zero_division=0)
rec_w    = recall_score(all_labels, all_preds, average="weighted", zero_division=0)
f1_w     = f1_score(all_labels, all_preds, average="weighted", zero_division=0)
prec_m   = precision_score(all_labels, all_preds, average="macro", zero_division=0)
rec_m    = recall_score(all_labels, all_preds, average="macro", zero_division=0)
f1_m     = f1_score(all_labels, all_preds, average="macro", zero_division=0)

metrics = {
    "model":    "V2_CustomCNN",
    "accuracy": round(acc,  4),
    "precision": round(prec_w, 4),
    "recall":   round(rec_w, 4),
    "f1":       round(f1_w,  4),
    "precision_macro": round(prec_m, 4),
    "recall_macro":    round(rec_m,  4),
    "f1_macro":        round(f1_m,   4),
    "best_epoch": int(ckpt["epoch"]),
    "training_time_min": round(elapsed / 60, 2),
}
with open(METRICS_DIR / "v2_metrics.json", "w") as f:
    json.dump(metrics, f, indent=2)

print("── V2 Metrics ─────────────────────────")
for k, v in metrics.items():
    print(f"  {k}: {v}")
print("Saved to results/metrics/v2_metrics.json ✅")
# Out:
# ── V2 Metrics ─────────────────────────
#   model: V2_CustomCNN
#   accuracy: 0.9954
#   precision: 0.9954
#   recall: 0.9954
#   f1: 0.9954
#   precision_macro: 0.9938
#   recall_macro: 0.9936
#   f1_macro: 0.9937
#   best_epoch: 96
#   training_time_min: 204.41
# Saved to results/metrics/v2_metrics.json ✅

# %%
# ── Cell 6: Training Curves ───────────────────────────────────────────────────
fig, axes = plt.subplots(1, 2, figsize=(14, 5))

epochs_ran = range(1, len(history["train_loss"]) + 1)

axes[0].plot(epochs_ran, history["train_loss"], label="Train Loss")
axes[0].plot(epochs_ran, history["val_loss"],   label="Val Loss")
axes[0].set_title("Loss per Epoch")
axes[0].set_xlabel("Epoch")
axes[0].set_ylabel("Cross-Entropy Loss")
axes[0].legend()
axes[0].grid(True, alpha=0.3)

axes[1].plot(epochs_ran, history["train_acc"], label="Train Accuracy")
axes[1].plot(epochs_ran, history["val_acc"],   label="Val Accuracy")
axes[1].set_title("Accuracy per Epoch")
axes[1].set_xlabel("Epoch")
axes[1].set_ylabel("Accuracy")
axes[1].legend()
axes[1].grid(True, alpha=0.3)

plt.suptitle("V2 Custom CNN — Training Curves", fontsize=14, fontweight="bold")
plt.tight_layout()
out_path = PLOTS_DIR / "v2_training_curves.png"
plt.savefig(out_path, dpi=150, bbox_inches="tight")
plt.show()
print(f"Saved: {out_path} ✅")
# Out:
# Saved: /Users/marco/Documents/repos/ComputerVisionProject/results/plots/v2_training_curves.png ✅

# %%
# ── Cell 7: Confusion Matrix ──────────────────────────────────────────────────
cm = confusion_matrix(all_labels, all_preds)

fig, ax = plt.subplots(figsize=(20, 18))
sns.heatmap(cm, annot=False, fmt="d", cmap="Blues",
            xticklabels=CLASS_NAMES, yticklabels=CLASS_NAMES, ax=ax)
ax.set_xlabel("Predicted", fontsize=12)
ax.set_ylabel("True", fontsize=12)
ax.set_title(f"V2 Custom CNN — Confusion Matrix\nAccuracy: {acc:.4f}", fontsize=14)
plt.xticks(rotation=90, fontsize=7)
plt.yticks(rotation=0,  fontsize=7)
plt.tight_layout()
out_path = PLOTS_DIR / "v2_confusion_matrix.png"
plt.savefig(out_path, dpi=150, bbox_inches="tight")
plt.show()
print(f"Saved: {out_path} ✅")

# Per-class F1
f1_per_class = f1_score(all_labels, all_preds, average=None, zero_division=0)
fig2, ax2 = plt.subplots(figsize=(18, 5))
bars = ax2.bar(CLASS_NAMES, f1_per_class, color="steelblue")
ax2.set_xticks(range(len(CLASS_NAMES)))
ax2.set_xticklabels(CLASS_NAMES, rotation=90, fontsize=7)
ax2.set_ylabel("F1 Score")
ax2.set_title("V2 Custom CNN — Per-class F1")
ax2.set_ylim(0, 1.05)
ax2.axhline(f1_per_class.mean(), color="red", linestyle="--", label=f"Mean: {f1_per_class.mean():.3f}")
ax2.legend()
plt.tight_layout()
out_path2 = PLOTS_DIR / "v2_f1_per_class.png"
plt.savefig(out_path2, dpi=150, bbox_inches="tight")
plt.show()
print(f"Saved: {out_path2} ✅")
print("\nDone! Notebook 02 complete.")
# Out:
# Saved: /Users/marco/Documents/repos/ComputerVisionProject/results/plots/v2_confusion_matrix.png ✅
# Saved: /Users/marco/Documents/repos/ComputerVisionProject/results/plots/v2_f1_per_class.png ✅
#
# Done! Notebook 02 complete.
