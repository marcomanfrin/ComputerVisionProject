# %% [markdown]
# # V2 - Custom CNN
# ## Plant Disease Detection — PyTorch CNN from scratch (38 classes)

# %%
# ── Cell 1: Setup & Imports ───────────────────────────────────────────────────
import sys, os, json, time, copy
from pathlib import Path

import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from tqdm import tqdm

import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader
from torchvision import datasets, transforms

from sklearn.metrics import (accuracy_score, precision_score,
                             recall_score, f1_score, confusion_matrix,
                             classification_report)

# ── Paths ─────────────────────────────────────────────────────────────────────
PROJECT_ROOT = Path("..").resolve()
DATA_DIR     = PROJECT_ROOT / "data" / "processed"
RESULTS_DIR  = PROJECT_ROOT / "results"
MODELS_DIR   = RESULTS_DIR / "models" / "v2_custom_cnn"
METRICS_DIR  = RESULTS_DIR / "metrics"
PLOTS_DIR    = RESULTS_DIR / "plots"

for d in [MODELS_DIR, METRICS_DIR, PLOTS_DIR]:
    d.mkdir(parents=True, exist_ok=True)

# ── Device (MPS on Apple Silicon, CUDA if available, otherwise CPU) ───────────
if torch.backends.mps.is_available():
    DEVICE = torch.device("mps")
elif torch.cuda.is_available():
    DEVICE = torch.device("cuda")
else:
    DEVICE = torch.device("cpu")

print(f"Device: {DEVICE}")
print(f"PyTorch: {torch.__version__}")

# ── Hyperparameters ───────────────────────────────────────────────────────────
IMG_SIZE    = 224
BATCH_SIZE  = 64   # MPS handles larger batches than CPU
LR          = 1e-3
EPOCHS      = 100
PATIENCE    = 10
NUM_WORKERS = 0    # on MPS, DataLoaders run with num_workers=0

FAST_MODE = False
print(f"Fast mode: {FAST_MODE}")
# Out:
# Device: mps
# PyTorch: 2.12.0
# Fast mode: False

# %%
# ── Cell 2: Dataset & DataLoaders ─────────────────────────────────────────────
IMAGENET_MEAN = [0.485, 0.456, 0.406]
IMAGENET_STD  = [0.229, 0.224, 0.225]

train_transform = transforms.Compose([
    transforms.Resize((IMG_SIZE, IMG_SIZE)),
    transforms.RandomRotation(15),
    transforms.RandomHorizontalFlip(),
    transforms.ColorJitter(brightness=0.2, contrast=0.2, saturation=0.2),
    transforms.RandomAffine(degrees=10, translate=(0.1, 0.1)),
    transforms.ToTensor(),
    transforms.Normalize(IMAGENET_MEAN, IMAGENET_STD),
])

val_test_transform = transforms.Compose([
    transforms.Resize((IMG_SIZE, IMG_SIZE)),
    transforms.ToTensor(),
    transforms.Normalize(IMAGENET_MEAN, IMAGENET_STD),
])

train_dataset = datasets.ImageFolder(DATA_DIR / "train", transform=train_transform)
val_dataset   = datasets.ImageFolder(DATA_DIR / "val",   transform=val_test_transform)
test_dataset  = datasets.ImageFolder(DATA_DIR / "test",  transform=val_test_transform)

# optional: subsample for quick tests on CPU
if FAST_MODE:
    def subsample(ds, frac=0.1):
        n = max(1, int(len(ds) * frac))
        idx = torch.randperm(len(ds))[:n].tolist()
        return torch.utils.data.Subset(ds, idx)
    train_dataset = subsample(train_dataset)
    val_dataset   = subsample(val_dataset)
    test_dataset  = subsample(test_dataset)

train_loader = DataLoader(train_dataset, batch_size=BATCH_SIZE, shuffle=True,
                          num_workers=NUM_WORKERS, pin_memory=True)
val_loader   = DataLoader(val_dataset,   batch_size=BATCH_SIZE, shuffle=False,
                          num_workers=NUM_WORKERS, pin_memory=True)
test_loader  = DataLoader(test_dataset,  batch_size=BATCH_SIZE, shuffle=False,
                          num_workers=NUM_WORKERS, pin_memory=True)

CLASS_NAMES = train_dataset.classes if hasattr(train_dataset, "classes") else train_dataset.dataset.classes
NUM_CLASSES = len(CLASS_NAMES)

print(f"Classes: {NUM_CLASSES}")
print(f"Train: {len(train_dataset)} | Val: {len(val_dataset)} | Test: {len(test_dataset)}")
# Out:
# Classi: 38
# Train: 70295 | Val: 8777 | Test: 8795

# %%
# ── Cell 3: CNN Model (~0.66M parameters) ────────────────────────────────────
class ConvBlock(nn.Module):
    def __init__(self, in_ch, out_ch):
        super().__init__()
        self.block = nn.Sequential(
            nn.Conv2d(in_ch, out_ch, kernel_size=3, padding=1, bias=False),
            nn.BatchNorm2d(out_ch),
            nn.ReLU(inplace=True),
        )
    def forward(self, x):
        return self.block(x)


class PlantDiseaseNet(nn.Module):
    """4 Conv+BN+ReLU blocks → GlobalAvgPool → Dense 512→256→num_classes."""
    def __init__(self, num_classes=38):
        super().__init__()
        self.features = nn.Sequential(
            ConvBlock(3,   32), nn.MaxPool2d(2),   # → (B, 32, 112, 112)
            ConvBlock(32,  64), nn.MaxPool2d(2),   # → (B, 64,  56,  56)
            ConvBlock(64, 128), nn.MaxPool2d(2),   # → (B,128,  28,  28)
            ConvBlock(128,256),                     # → (B,256,  28,  28)
        )
        self.pool = nn.AdaptiveAvgPool2d(1)         # → (B,256,   1,   1)
        self.classifier = nn.Sequential(
            nn.Linear(256, 512), nn.ReLU(inplace=True), nn.Dropout(0.5),
            nn.Linear(512, 256), nn.ReLU(inplace=True), nn.Dropout(0.3),
            nn.Linear(256, num_classes),
        )

    def forward(self, x):
        x = self.features(x)
        x = self.pool(x).flatten(1)
        return self.classifier(x)


model = PlantDiseaseNet(num_classes=NUM_CLASSES).to(DEVICE)
total_params = sum(p.numel() for p in model.parameters())
print(f"Total parameters: {total_params:,}  (~{total_params/1e6:.1f}M)")

criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.parameters(), lr=LR)
scheduler = optim.lr_scheduler.ReduceLROnPlateau(optimizer, factor=0.1, patience=5)
print("Model, loss and optimizer ready ✅")
# Out:
# Parametri totali: 661,574  (~0.7M)
# Modello, loss e optimizer pronti ✅

# %%
# ── Cell 4: Training Loop with Early Stopping (with resume) ──────────────────
def train_epoch(model, loader, criterion, optimizer, device):
    model.train()
    running_loss, correct, total = 0.0, 0, 0
    for images, labels in loader:
        images, labels = images.to(device), labels.to(device)
        optimizer.zero_grad()
        outputs = model(images)
        loss = criterion(outputs, labels)
        loss.backward()
        optimizer.step()
        running_loss += loss.item() * images.size(0)
        correct += (outputs.argmax(1) == labels).sum().item()
        total   += images.size(0)
    return running_loss / total, correct / total


def validate(model, loader, criterion, device):
    model.eval()
    running_loss, correct, total = 0.0, 0, 0
    with torch.no_grad():
        for images, labels in loader:
            images, labels = images.to(device), labels.to(device)
            outputs = model(images)
            loss = criterion(outputs, labels)
            running_loss += loss.item() * images.size(0)
            correct += (outputs.argmax(1) == labels).sum().item()
            total   += images.size(0)
    return running_loss / total, correct / total


checkpoint_path = MODELS_DIR / "checkpoint.pth"

# ── Resume from checkpoint if it exists ──────────────────────────────────────
if checkpoint_path.exists():
    ckpt = torch.load(checkpoint_path, map_location=DEVICE, weights_only=False)
    model.load_state_dict(ckpt["model_state_dict"])
    best_val_loss  = ckpt["val_loss"]
    start_epoch    = ckpt["epoch"] + 1
    history        = ckpt.get("history", {"train_loss": [], "val_loss": [], "train_acc": [], "val_acc": []})
    print(f"Resumed from epoch {ckpt['epoch']} — best val loss {best_val_loss:.4f}, val acc {ckpt['val_acc']:.4f}")
else:
    best_val_loss  = float("inf")
    start_epoch    = 1
    history        = {"train_loss": [], "val_loss": [], "train_acc": [], "val_acc": []}
    print("No checkpoint found, training from scratch.")

best_model_wts = copy.deepcopy(model.state_dict())
patience_count = 0
t0 = time.time()

print(f"Training on {DEVICE} — epoch {start_epoch}→{EPOCHS}, early stopping patience={PATIENCE}\n")

for epoch in range(start_epoch, EPOCHS + 1):
    tr_loss, tr_acc = train_epoch(model, train_loader, criterion, optimizer, DEVICE)
    vl_loss, vl_acc = validate(model, val_loader, criterion, DEVICE)
    scheduler.step(vl_loss)

    history["train_loss"].append(tr_loss)
    history["val_loss"].append(vl_loss)
    history["train_acc"].append(tr_acc)
    history["val_acc"].append(vl_acc)

    improved = vl_loss < best_val_loss
    if improved:
        best_val_loss  = vl_loss
        best_model_wts = copy.deepcopy(model.state_dict())
        torch.save({"epoch": epoch,
                    "model_state_dict": best_model_wts,
                    "val_loss": best_val_loss,
                    "val_acc": vl_acc,
                    "history": history}, checkpoint_path)
        patience_count = 0
        tag = " ✓ saved"
    else:
        patience_count += 1
        tag = f" (patience {patience_count}/{PATIENCE})"

    print(f"Epoch {epoch:3d}/{EPOCHS} | "
          f"train loss {tr_loss:.4f} acc {tr_acc:.4f} | "
          f"val loss {vl_loss:.4f} acc {vl_acc:.4f}{tag}")

    if patience_count >= PATIENCE:
        print(f"\nEarly stopping at epoch {epoch}.")
        break

elapsed = time.time() - t0
print(f"\nTraining complete in {elapsed/60:.1f} additional min")
print(f"Best val loss: {best_val_loss:.4f}")

with open(METRICS_DIR / "v2_history.json", "w") as f:
    json.dump(history, f, indent=2)
print("History saved ✅")
# Out:
# Nessun checkpoint trovato, training da zero.
# Training su mps — epoch 1→100, early stopping patience=10
# /Users/marco/Documents/repos/ComputerVisionProject/.venv/lib/python3.13/site-packages/torch/utils/data/dataloader.py:752: UserWarning: 'pin_memory' argument is set as true but not supported on MPS now, device pinned memory won't be used.
#   super().__init__(loader)
# Epoch   1/100 | train loss 1.6157 acc 0.5054 | val loss 0.8367 acc 0.7359 ✓ saved
# Epoch   2/100 | train loss 0.8001 acc 0.7434 | val loss 0.4672 acc 0.8455 ✓ saved
# Epoch   3/100 | train loss 0.5832 acc 0.8120 | val loss 0.3732 acc 0.8764 ✓ saved
# Epoch   4/100 | train loss 0.4710 acc 0.8471 | val loss 0.3435 acc 0.8849 ✓ saved
# Epoch   5/100 | train loss 0.3887 acc 0.8734 | val loss 0.2041 acc 0.9326 ✓ saved
# Epoch   6/100 | train loss 0.3328 acc 0.8908 | val loss 0.1850 acc 0.9382 ✓ saved
# Epoch   7/100 | train loss 0.2871 acc 0.9059 | val loss 0.1372 acc 0.9523 ✓ saved
# Epoch   8/100 | train loss 0.2549 acc 0.9181 | val loss 0.1335 acc 0.9567 ✓ saved
# Epoch   9/100 | train loss 0.2285 acc 0.9261 | val loss 0.1479 acc 0.9500 (patience 1/10)
# Epoch  10/100 | train loss 0.2077 acc 0.9334 | val loss 0.0938 acc 0.9690 ✓ saved
# Epoch  11/100 | train loss 0.1913 acc 0.9390 | val loss 0.0836 acc 0.9723 ✓ saved
# Epoch  12/100 | train loss 0.1772 acc 0.9430 | val loss 0.0917 acc 0.9686 (patience 1/10)
# Epoch  13/100 | train loss 0.1553 acc 0.9502 | val loss 0.0968 acc 0.9682 (patience 2/10)
# Epoch  14/100 | train loss 0.1549 acc 0.9502 | val loss 0.2007 acc 0.9386 (patience 3/10)
# Epoch  15/100 | train loss 0.1385 acc 0.9551 | val loss 0.0908 acc 0.9670 (patience 4/10)
# Epoch  16/100 | train loss 0.1302 acc 0.9575 | val loss 0.0860 acc 0.9723 (patience 5/10)
# Epoch  17/100 | train loss 0.1217 acc 0.9605 | val loss 0.0911 acc 0.9704 (patience 6/10)
# Epoch  18/100 | train loss 0.0713 acc 0.9769 | val loss 0.0277 acc 0.9918 ✓ saved
# Epoch  19/100 | train loss 0.0587 acc 0.9813 | val loss 0.0258 acc 0.9916 ✓ saved
# Epoch  20/100 | train loss 0.0531 acc 0.9823 | val loss 0.0268 acc 0.9913 (patience 1/10)
# Epoch  21/100 | train loss 0.0527 acc 0.9830 | val loss 0.0251 acc 0.9913 ✓ saved
# Epoch  22/100 | train loss 0.0490 acc 0.9845 | val loss 0.0256 acc 0.9912 (patience 1/10)
# Epoch  23/100 | train loss 0.0476 acc 0.9847 | val loss 0.0277 acc 0.9912 (patience 2/10)
# Epoch  24/100 | train loss 0.0468 acc 0.9846 | val loss 0.0233 acc 0.9924 ✓ saved
# Epoch  25/100 | train loss 0.0454 acc 0.9847 | val loss 0.0222 acc 0.9919 ✓ saved
# Epoch  26/100 | train loss 0.0431 acc 0.9860 | val loss 0.0267 acc 0.9919 (patience 1/10)
# Epoch  27/100 | train loss 0.0424 acc 0.9860 | val loss 0.0268 acc 0.9918 (patience 2/10)
# Epoch  28/100 | train loss 0.0412 acc 0.9863 | val loss 0.0212 acc 0.9926 ✓ saved
# Epoch  29/100 | train loss 0.0420 acc 0.9864 | val loss 0.0208 acc 0.9924 ✓ saved
# Epoch  30/100 | train loss 0.0404 acc 0.9862 | val loss 0.0221 acc 0.9932 (patience 1/10)
# Epoch  31/100 | train loss 0.0388 acc 0.9871 | val loss 0.0197 acc 0.9934 ✓ saved
# Epoch  32/100 | train loss 0.0392 acc 0.9868 | val loss 0.0232 acc 0.9919 (patience 1/10)
# Epoch  33/100 | train loss 0.0373 acc 0.9874 | val loss 0.0184 acc 0.9940 ✓ saved
# Epoch  34/100 | train loss 0.0383 acc 0.9870 | val loss 0.0196 acc 0.9928 (patience 1/10)
# Epoch  35/100 | train loss 0.0357 acc 0.9878 | val loss 0.0194 acc 0.9937 (patience 2/10)
# Epoch  36/100 | train loss 0.0368 acc 0.9883 | val loss 0.0204 acc 0.9931 (patience 3/10)
# Epoch  37/100 | train loss 0.0361 acc 0.9883 | val loss 0.0183 acc 0.9936 ✓ saved
# Epoch  38/100 | train loss 0.0343 acc 0.9890 | val loss 0.0196 acc 0.9938 (patience 1/10)
# Epoch  39/100 | train loss 0.0342 acc 0.9887 | val loss 0.0168 acc 0.9942 ✓ saved
# Epoch  40/100 | train loss 0.0331 acc 0.9890 | val loss 0.0201 acc 0.9938 (patience 1/10)
# Epoch  41/100 | train loss 0.0336 acc 0.9889 | val loss 0.0193 acc 0.9936 (patience 2/10)
# Epoch  42/100 | train loss 0.0342 acc 0.9891 | val loss 0.0184 acc 0.9934 (patience 3/10)
# Epoch  43/100 | train loss 0.0333 acc 0.9889 | val loss 0.0180 acc 0.9942 (patience 4/10)
# Epoch  44/100 | train loss 0.0332 acc 0.9889 | val loss 0.0164 acc 0.9938 ✓ saved
# Epoch  45/100 | train loss 0.0315 acc 0.9898 | val loss 0.0164 acc 0.9944 (patience 1/10)
# Epoch  46/100 | train loss 0.0298 acc 0.9899 | val loss 0.0159 acc 0.9945 ✓ saved
# Epoch  47/100 | train loss 0.0323 acc 0.9890 | val loss 0.0155 acc 0.9948 ✓ saved
# Epoch  48/100 | train loss 0.0287 acc 0.9910 | val loss 0.0172 acc 0.9944 (patience 1/10)
# Epoch  49/100 | train loss 0.0316 acc 0.9894 | val loss 0.0162 acc 0.9953 (patience 2/10)
# Epoch  50/100 | train loss 0.0292 acc 0.9905 | val loss 0.0156 acc 0.9950 (patience 3/10)
# Epoch  51/100 | train loss 0.0279 acc 0.9907 | val loss 0.0166 acc 0.9944 (patience 4/10)
# Epoch  52/100 | train loss 0.0278 acc 0.9907 | val loss 0.0142 acc 0.9962 ✓ saved
# Epoch  53/100 | train loss 0.0275 acc 0.9908 | val loss 0.0176 acc 0.9945 (patience 1/10)
# Epoch  54/100 | train loss 0.0277 acc 0.9907 | val loss 0.0161 acc 0.9951 (patience 2/10)
# Epoch  55/100 | train loss 0.0285 acc 0.9904 | val loss 0.0143 acc 0.9953 (patience 3/10)
# Epoch  56/100 | train loss 0.0273 acc 0.9910 | val loss 0.0140 acc 0.9956 ✓ saved
# Epoch  57/100 | train loss 0.0277 acc 0.9902 | val loss 0.0157 acc 0.9945 (patience 1/10)
# Epoch  58/100 | train loss 0.0278 acc 0.9908 | val loss 0.0199 acc 0.9937 (patience 2/10)
# Epoch  59/100 | train loss 0.0258 acc 0.9916 | val loss 0.0148 acc 0.9949 (patience 3/10)
# Epoch  60/100 | train loss 0.0270 acc 0.9913 | val loss 0.0135 acc 0.9952 ✓ saved
# Epoch  61/100 | train loss 0.0269 acc 0.9909 | val loss 0.0149 acc 0.9953 (patience 1/10)
# Epoch  62/100 | train loss 0.0266 acc 0.9913 | val loss 0.0142 acc 0.9953 (patience 2/10)
# Epoch  63/100 | train loss 0.0253 acc 0.9916 | val loss 0.0130 acc 0.9951 ✓ saved
# Epoch  64/100 | train loss 0.0266 acc 0.9913 | val loss 0.0136 acc 0.9949 (patience 1/10)
# Epoch  65/100 | train loss 0.0260 acc 0.9909 | val loss 0.0168 acc 0.9949 (patience 2/10)
# Epoch  66/100 | train loss 0.0240 acc 0.9918 | val loss 0.0154 acc 0.9953 (patience 3/10)
# Epoch  67/100 | train loss 0.0246 acc 0.9917 | val loss 0.0159 acc 0.9946 (patience 4/10)
# Epoch  68/100 | train loss 0.0245 acc 0.9920 | val loss 0.0145 acc 0.9957 (patience 5/10)
# Epoch  69/100 | train loss 0.0246 acc 0.9914 | val loss 0.0157 acc 0.9949 (patience 6/10)
# Epoch  70/100 | train loss 0.0202 acc 0.9934 | val loss 0.0134 acc 0.9957 (patience 7/10)
# Epoch  71/100 | train loss 0.0206 acc 0.9930 | val loss 0.0130 acc 0.9957 ✓ saved
# Epoch  72/100 | train loss 0.0188 acc 0.9937 | val loss 0.0135 acc 0.9956 (patience 1/10)
# Epoch  73/100 | train loss 0.0194 acc 0.9937 | val loss 0.0129 acc 0.9956 ✓ saved
# Epoch  74/100 | train loss 0.0195 acc 0.9934 | val loss 0.0129 acc 0.9954 (patience 1/10)
# Epoch  75/100 | train loss 0.0191 acc 0.9935 | val loss 0.0126 acc 0.9953 ✓ saved
# Epoch  76/100 | train loss 0.0192 acc 0.9937 | val loss 0.0125 acc 0.9960 ✓ saved
# Epoch  77/100 | train loss 0.0201 acc 0.9935 | val loss 0.0130 acc 0.9957 (patience 1/10)
# Epoch  78/100 | train loss 0.0191 acc 0.9936 | val loss 0.0132 acc 0.9952 (patience 2/10)
# Epoch  79/100 | train loss 0.0183 acc 0.9943 | val loss 0.0125 acc 0.9957 (patience 3/10)
# Epoch  80/100 | train loss 0.0194 acc 0.9934 | val loss 0.0115 acc 0.9961 ✓ saved
# Epoch  81/100 | train loss 0.0196 acc 0.9934 | val loss 0.0126 acc 0.9956 (patience 1/10)
# Epoch  82/100 | train loss 0.0190 acc 0.9939 | val loss 0.0123 acc 0.9960 (patience 2/10)
# Epoch  83/100 | train loss 0.0192 acc 0.9935 | val loss 0.0121 acc 0.9959 (patience 3/10)
# Epoch  84/100 | train loss 0.0189 acc 0.9938 | val loss 0.0121 acc 0.9957 (patience 4/10)
# Epoch  85/100 | train loss 0.0182 acc 0.9938 | val loss 0.0123 acc 0.9958 (patience 5/10)
# Epoch  86/100 | train loss 0.0181 acc 0.9938 | val loss 0.0121 acc 0.9959 (patience 6/10)
# Epoch  87/100 | train loss 0.0188 acc 0.9938 | val loss 0.0128 acc 0.9961 (patience 7/10)
# Epoch  88/100 | train loss 0.0186 acc 0.9938 | val loss 0.0124 acc 0.9960 (patience 8/10)
# Epoch  89/100 | train loss 0.0181 acc 0.9938 | val loss 0.0120 acc 0.9961 (patience 9/10)
# Epoch  90/100 | train loss 0.0182 acc 0.9941 | val loss 0.0119 acc 0.9959 (patience 10/10)
#
# Early stopping a epoch 90.
#
# Training completato in 294.1 min aggiuntivi
# Best val loss: 0.0115
# History salvata ✅

# %%
# ── Cell 5: Evaluate on the Test Set ──────────────────────────────────────────
# load the best checkpoint
ckpt = torch.load(checkpoint_path, map_location=DEVICE, weights_only=False)
model.load_state_dict(ckpt["model_state_dict"])
model.eval()

all_preds, all_labels = [], []
with torch.no_grad():
    for images, labels in test_loader:
        images = images.to(DEVICE)
        preds  = model(images).argmax(1).cpu()
        all_preds.extend(preds.tolist())
        all_labels.extend(labels.tolist())

acc  = accuracy_score(all_labels, all_preds)
prec = precision_score(all_labels, all_preds, average="weighted", zero_division=0)
rec  = recall_score(all_labels, all_preds, average="weighted", zero_division=0)
f1   = f1_score(all_labels, all_preds, average="weighted", zero_division=0)

metrics = {
    "model":    "V2_CustomCNN",
    "accuracy": round(acc,  4),
    "precision": round(prec, 4),
    "recall":   round(rec,  4),
    "f1":       round(f1,   4),
    "best_epoch": int(ckpt["epoch"]),
    "training_time_min": round(elapsed / 60, 2),
}
with open(METRICS_DIR / "v2_metrics.json", "w") as f:
    json.dump(metrics, f, indent=2)

print("── V2 Metrics ─────────────────────────")
for k, v in metrics.items():
    print(f"  {k}: {v}")
print("Saved to results/metrics/v2_metrics.json ✅")
# Out:
# ── V2 Metrics ─────────────────────────
#   model: V2_CustomCNN
#   accuracy: 0.9966
#   precision: 0.9966
#   recall: 0.9966
#   f1: 0.9966
#   best_epoch: 80
#   training_time_min: 294.14
# Salvato in results/metrics/v2_metrics.json ✅

# %%
# ── Cell 6: Training Curves ───────────────────────────────────────────────────
fig, axes = plt.subplots(1, 2, figsize=(14, 5))

epochs_ran = range(1, len(history["train_loss"]) + 1)

axes[0].plot(epochs_ran, history["train_loss"], label="Train Loss")
axes[0].plot(epochs_ran, history["val_loss"],   label="Val Loss")
axes[0].set_title("Loss per Epoch")
axes[0].set_xlabel("Epoch")
axes[0].set_ylabel("Cross-Entropy Loss")
axes[0].legend()
axes[0].grid(True, alpha=0.3)

axes[1].plot(epochs_ran, history["train_acc"], label="Train Accuracy")
axes[1].plot(epochs_ran, history["val_acc"],   label="Val Accuracy")
axes[1].set_title("Accuracy per Epoch")
axes[1].set_xlabel("Epoch")
axes[1].set_ylabel("Accuracy")
axes[1].legend()
axes[1].grid(True, alpha=0.3)

plt.suptitle("V2 Custom CNN — Training Curves", fontsize=14, fontweight="bold")
plt.tight_layout()
out_path = PLOTS_DIR / "v2_training_curves.png"
plt.savefig(out_path, dpi=150, bbox_inches="tight")
plt.show()
print(f"Saved: {out_path} ✅")
# Out:
# Salvato: /Users/marco/Documents/repos/ComputerVisionProject/results/plots/v2_training_curves.png ✅

# %%
# ── Cell 7: Confusion Matrix ──────────────────────────────────────────────────
cm = confusion_matrix(all_labels, all_preds)

fig, ax = plt.subplots(figsize=(20, 18))
sns.heatmap(cm, annot=False, fmt="d", cmap="Blues",
            xticklabels=CLASS_NAMES, yticklabels=CLASS_NAMES, ax=ax)
ax.set_xlabel("Predicted", fontsize=12)
ax.set_ylabel("True", fontsize=12)
ax.set_title(f"V2 Custom CNN — Confusion Matrix\nAccuracy: {acc:.4f}", fontsize=14)
plt.xticks(rotation=90, fontsize=7)
plt.yticks(rotation=0,  fontsize=7)
plt.tight_layout()
out_path = PLOTS_DIR / "v2_confusion_matrix.png"
plt.savefig(out_path, dpi=150, bbox_inches="tight")
plt.show()
print(f"Saved: {out_path} ✅")

# Per-class F1
f1_per_class = f1_score(all_labels, all_preds, average=None, zero_division=0)
fig2, ax2 = plt.subplots(figsize=(18, 5))
bars = ax2.bar(CLASS_NAMES, f1_per_class, color="steelblue")
ax2.set_xticks(range(len(CLASS_NAMES)))
ax2.set_xticklabels(CLASS_NAMES, rotation=90, fontsize=7)
ax2.set_ylabel("F1 Score")
ax2.set_title("V2 Custom CNN — Per-class F1")
ax2.set_ylim(0, 1.05)
ax2.axhline(f1_per_class.mean(), color="red", linestyle="--", label=f"Mean: {f1_per_class.mean():.3f}")
ax2.legend()
plt.tight_layout()
out_path2 = PLOTS_DIR / "v2_f1_per_class.png"
plt.savefig(out_path2, dpi=150, bbox_inches="tight")
plt.show()
print(f"Saved: {out_path2} ✅")
print("\nDone! Notebook 02 complete.")
# Out:
# Salvato: /Users/marco/Documents/repos/ComputerVisionProject/results/plots/v2_confusion_matrix.png ✅
# Salvato: /Users/marco/Documents/repos/ComputerVisionProject/results/plots/v2_f1_per_class.png ✅
#
# Done! Notebook 02 completato.
